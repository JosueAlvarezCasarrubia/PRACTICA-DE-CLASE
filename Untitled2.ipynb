# %% [markdown]
# <a href="https://colab.research.google.com/github/JosueAlvarezCasarrubia/PRACTICA-DE-CLASE-JOSUE/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ALGORITMO:
#
#
# ![Captura de pantalla 2024-08-29 162116.png](data:image/png;base64,...)

# %% [markdown]
# PSEUDOCODIGO
#
# start
#
# program determinar_estadO_iIMC
#
# //PROGRAMA PARA DETERMINAR EL ESTADO DE PESO DE UNA PERSONA A PARTR DEL IMC
#
# Declare float peso
#
#
# Declare float altura
#
#
# Display "ingrese la altura en (in)"
#
#
# input altura
#
# Display "ingrese el peso en (lb)"
#
# input peso
#
# set imc = peso * 703 / altura^2
#
# Display "su IMC es de ", imc
#
# if imc < 18.5 then
#
#
#           Display "está debajo del peso recomendado."
#
#
# Else if imc < 25 then
#
#
#            display " esta en el peso optimo"
#
#
# Esle
#
#
#            Display "esta con sobrepeso"
# End if

# %% [markdown]
# 11.Calculadora de Tiempo
# Diseña un programa que solicite al usuario ingresar una cantidad de segundos y funcione de la
# siguiente manera:
# - Hay 60 segundos en un minuto. Si la cantidad de segundos ingresada por el usuario es mayor o
# igual a 60, el programa debe mostrar la cantidad de minutos en esa cantidad de segundos.
# - Hay 3600 segundos en una hora. Si la cantidad de segundos ingresada por el usuario es mayor
# o igual a 3600, el programa debe mostrar la cantidad de horas en esa cantidad de segundos.
# - Hay 86400 segundos en un día. Si la cantidad de segundos ingresada por el usuario es mayor o
# igual a 86400, el programa debe mostrar la cantidad de días en esa cantidad de segundos
#
#
# ALGORITMO:
#
# -INICIAR
# -PERDIR INGRESAR UNA CANTIDAD DE SEGUNDOS
#
#
# -SI EL USUARIO INGRESA 86400 SEGUNDOS O MAS SE DEBE MOSTRAR ESE TIEMPO EN DIAS, PARA ELLO SE CALCULAN LOS DIAS DE LA SIGUIENTE FORMA:
# DIAS = SEGUNDOS / 86400
#
#
# -SI EL USUARIO INGRESA 3600 SEGUNDOS O MAS SE DEBE MOSTRAR ESE TIEMPO EN HORAS, PARA ELLO SE CALCULAN LAS HORAS DE LA SIGUIENTE FORMA:
# HORAS = SEGUNDOS / 3600
#
# -SI EL USUARIO INGRESA 60 SEGUNDOS O MAS SE DEBE MOSTRAR ESE TIEMPO EN MINUTOS, PARA ELLO SE CALCULAN LOS MINUTOS DE LA SIGUIENTE FORMA:
# MINUTOS = SEGUNDOS / 60
#
#
# -FINALIZAR
#
#
#
#
#
#
#
#
# PSEUDOCODIGO:
#
# start
#
# Display "ingrese una cantidad de segundos "
# input segundos
#
#
# if segundos > 86400 then
#       dias = segundos / 86400
#       Display "la cantidad de dias es: ",dias
#
# Else if segundos > 3600 then
#       horas  = segundos / 3600
#       Display "la cantidad de horas es: ",horas
#
# Else splay "esta con sobrepeso" segundos >= 60 then
#        minutoas  = segundos / 60
#       Display "la cantidad de minutos es: ",minutos
#
# End if
